# %%
import pandas as pd

# %%
df = pd.read_csv("../Data-Analysis-Datasets/Datasets-Practice/hr_data.csv")
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
df.head()       # first 5 rows
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
df.tail()       # last 5 rows
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department salary
# 14994              0     1                      0    support    low
# 14995              0     1                      0    support    low
# 14996              0     1                      0    support    low
# 14997              0     1                      0    support    low
# 14998              0     1                      0    support    low

# %%
print(df.describe())
print("-----------------------------------------")
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years
# count   14999.000000  14999.000000           14999.000000
# mean        0.144610      0.238083               0.021268
# std         0.351719      0.425924               0.144281
# ...

# %%
df.info()       # column info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
df.describe()   # summary statistics
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years
# count   14999.000000  14999.000000           14999.000000
# mean        0.144610      0.238083               0.021268
# std         0.351719      0.425924               0.144281
# ...

# %%
df['employee_id']            # select column
# Out:
# 0         1003
# 1         1005
# 2         1486
# 3         1038
# 4         1057
#          ...
# 14994    87670
# 14995    87673
# 14996    87679
# 14997    87681
# 14998    87684
# Name: employee_id, Length: 14999, dtype: int64

# %%
df.iloc[0]            # select row by index
# Out:
# employee_id               1003
# number_project               2
# average_montly_hours       157
# time_spend_company           3
# Work_accident                0
# left                         1
# promotion_last_5years        0
# department               sales
# salary                     low
# Name: 0, dtype: object

# %%
#Sorting
df.sort_values('number_project')
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 14984        87612               2                   148                   3
# 14982        87608               2                   137                   3
# 18            3794               2                   160                   3
# 16           58014               2                   160                   3
# 15            1113               2                   143                   3
# ...            ...             ...                   ...                 ...
# 73            1454               7                   295                   4
# 739          24446               7                   275                   4
# 740          24553               7                   291                   4
# 43            7010               7                   281                   4
# 54            1341               7                   307                   4
#
# ...

# %%
print(df.shape)
print("-----------------------------------------")
# Out:
# (14999, 9)
# -----------------------------------------

# %%
print(df.columns)
print("-----------------------------------------")
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary'],
#       dtype='object')
# -----------------------------------------

# %%
print(df.dtypes)
print("-----------------------------------------")
# Out:
# employee_id               int64
# number_project            int64
# average_montly_hours      int64
# time_spend_company        int64
# Work_accident             int64
# left                      int64
# promotion_last_5years     int64
# department               object
# salary                   object
# dtype: object
# -----------------------------------------

# %%
df['salary'].value_counts()
# Out:
# salary
# low       7316
# medium    6446
# high      1237
# Name: count, dtype: int64

# %%
df['department'].value_counts()
# Out:
# department
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: count, dtype: int64

# %%
df.sample()
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 11054        64843               4                   178                   2
#
#        Work_accident  left  promotion_last_5years department  salary
# 11054              0     0                      0    support  medium

# %%
df.sample(45)
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 6466         38166               2                   132                   3
# 1773         11031               6                   273                   4
# 4194         24853               3                   146                   3
# 7273         23804               5                   259                   4
# 4786         28258               4                   162                   2
# 8159         48248               4                   190                   2
# 14270        83372               4                   225                   5
# 3052         18282               4                   232                   3
# 4931         29121               5                   232                   3
# 3485         20934               4                   192                   2
# 8951         52921               4                   246                   3
# ...

# %%
df.loc[22]
# Out:
# employee_id               1158
# number_project               6
# average_montly_hours       304
# time_spend_company           4
# Work_accident                0
# left                         1
# promotion_last_5years        0
# department               sales
# salary                     low
# Name: 22, dtype: object

# %%
df.loc[22:100]
# Out:
#      employee_id  number_project  average_montly_hours  time_spend_company  \
# 22          1158               6                   304                   4
# 23          1166               2                   139                   3
# 24          1175               2                   158                   3
# 25          1184               5                   242                   5
# 26          1186               4                   239                   5
# ..           ...             ...                   ...                 ...
# 96          1610               6                   265                   4
# 97          1622               6                   279                   4
# 98          1639               6                   284                   4
# 99          1641               5                   221                   6
# 100         1642               2                   154                   3
#
#      Work_accident  left  promotion_last_5years department  salary
# ...

# %%
df.loc[[2,5,7],["department","salary"]]
# Out:
#   department  salary
# 2      sales  medium
# 5      sales     low
# 7      sales     low

# %%
df.loc[1:4, ["department","salary"]]
# Out:
#   department  salary
# 1      sales  medium
# 2      sales  medium
# 3      sales     low
# 4      sales     low

# %%
df.iloc[0]
# Out:
# employee_id               1003
# number_project               2
# average_montly_hours       157
# time_spend_company           3
# Work_accident                0
# left                         1
# promotion_last_5years        0
# department               sales
# salary                     low
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
df.iloc[:, 2]
# Out:
# 0        157
# 1        262
# 2        272
# 3        223
# 4        159
#         ...
# 14994    151
# 14995    160
# 14996    143
# 14997    280
# 14998    158
# Name: average_montly_hours, Length: 14999, dtype: int64

# %%
df.iloc[0:4, 1:3]
# Out:
#    number_project  average_montly_hours
# 0               2                   157
# 1               5                   262
# 2               7                   272
# 3               5                   223

# %%
df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
df.columns
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary'],
#       dtype='object')

# %%
df["department"].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
df[(df["department"] == "sales") & (df["salary"] == "low")]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# 5             1060               2                   153                   3
# 6             1061               6                   247                   4
# ...            ...             ...                   ...                 ...
# 14963        90813               6                   271                   4
# 14964        87480               6                   280                   4
# 14965        87497               2                   149                   3
# 14966        87500               5                   219                   5
# 14967        87507               2                   128                   3
#
# ...

# %%
df[(df["promotion_last_5years"] == 1) & (df["average_montly_hours"] > 4)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 82            1506               4                   139                   3
# 171           2016               2                   160                   3
# 287           2773               6                   292                   4
# 584           4300               2                   154                   3
# ...            ...             ...                   ...                 ...
# 14229        83135               2                   160                   3
# 14293        83468               4                   139                   3
# 14382        84032               2                   160                   3
# 14498        84776               6                   292                   4
# 14795        86564               2                   154                   3
#
# ...

# %%
# fetch the data of employees who got promotion  and working more than 4 hours
df[(df["promotion_last_5years"] == 1) & (df["time_spend_company"] > 4)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 1000          6792               4                   258                   5
# 4541         88646               3                   286                   6
# 4552         26968               4                   269                   5
# 4556         26993               4                   163                   5
# 4735         27931               6                   275                   5
# ...            ...             ...                   ...                 ...
# 14205        83010               3                   193                  10
# 14206        83017               3                   259                  10
# 14207        83019               5                   266                  10
# 14208        83020               3                   185                  10
# 14209        83025               3                   172                  10
#
# ...

# %%
df[df["left"].isnull()]
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary]
# Index: []

# %%
df[df["left"].notnull()]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...
