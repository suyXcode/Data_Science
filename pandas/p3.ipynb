# %%
import pandas as pd

# %% [markdown]
# # boolean values
#
# var[var["column_name"]=="value"]

# %%
df = pd.read_csv("../Data-Analysis-Datasets/Datasets-Practice/titanic.csv")
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
df[df["sex"]=="male"]
# Out:
#       pclass                                  name   sex      age  sibsp  \
# 1          1        Allison, Master. Hudson Trevor  male   0.9167      1
# 3          1  Allison, Mr. Hudson Joshua Creighton  male  30.0000      1
# 5          1                   Anderson, Mr. Harry  male  48.0000      0
# 7          1                Andrews, Mr. Thomas Jr  male  39.0000      0
# 9          1               Artagaveytia, Mr. Ramon  male  71.0000      0
# ...      ...                                   ...   ...      ...    ...
# 1302       3                     Yousif, Mr. Wazli  male      NaN      0
# 1303       3                 Yousseff, Mr. Gerious  male      NaN      0
# 1306       3             Zakarian, Mr. Mapriededer  male  26.5000      0
# 1307       3                   Zakarian, Mr. Ortin  male  27.0000      0
# 1308       3                    Zimmerman, Mr. Leo  male  29.0000      0
#
#       parch    ticket      fare    cabin embarked  survived
# ...

# %%
df[df["sex"]=="female"]
# Out:
#       pclass                                             name     sex   age  \
# 0          1                    Allen, Miss. Elisabeth Walton  female  29.0
# 2          1                     Allison, Miss. Helen Loraine  female   2.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 6          1                Andrews, Miss. Kornelia Theodosia  female  63.0
# 8          1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# ...      ...                                              ...     ...   ...
# 1286       3  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0
# 1290       3                 Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1304       3                             Zabour, Miss. Hileni  female  14.5
# 1305       3                            Zabour, Miss. Thamine  female   NaN
#
# ...

# %%
df[df["survived"]==1]
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 5          1                              Anderson, Mr. Harry    male
# 6          1                Andrews, Miss. Kornelia Theodosia  female
# 8          1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# ...      ...                                              ...     ...
# 1261       3                           Turkula, Mrs. (Hedwig)  female
# 1277       3                             Vartanian, Mr. David    male
# 1286       3  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female
# 1290       3                 Wilkes, Mrs. James (Ellen Needs)  female
# 1300       3          Yasbeck, Mrs. Antoni (Selini Alexander)  female
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df[df["survived"]==0]
# Out:
#       pclass                                             name     sex   age  \
# 2          1                     Allison, Miss. Helen Loraine  female   2.0
# 3          1             Allison, Mr. Hudson Joshua Creighton    male  30.0
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0
# 7          1                           Andrews, Mr. Thomas Jr    male  39.0
# 9          1                          Artagaveytia, Mr. Ramon    male  71.0
# ...      ...                                              ...     ...   ...
# 1304       3                             Zabour, Miss. Hileni  female  14.5
# 1305       3                            Zabour, Miss. Thamine  female   NaN
# 1306       3                        Zakarian, Mr. Mapriededer    male  26.5
# 1307       3                              Zakarian, Mr. Ortin    male  27.0
# 1308       3                               Zimmerman, Mr. Leo    male  29.0
#
# ...

# %%
#fetch the passenger data where the age is more than 50 on titanic dataset
df[df["age"] > 50]
# Out:
#       pclass                                           name     sex   age  \
# 6          1              Andrews, Miss. Kornelia Theodosia  female  63.0
# 8          1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 9          1                        Artagaveytia, Mr. Ramon    male  71.0
# 14         1           Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 33         1                       Bonnell, Miss. Elizabeth  female  58.0
# ...      ...                                            ...     ...   ...
# 1068       3                      Nysveen, Mr. Johan Hansen    male  61.0
# 1225       3                             Storey, Mr. Thomas    male  60.5
# 1235       3                            Svensson, Mr. Johan    male  74.0
# 1261       3                         Turkula, Mrs. (Hedwig)  female  63.0
# 1287       3               Widegren, Mr. Carl/Charles Peter    male  51.0
#
#       sibsp  parch    ticket     fare cabin embarked  survived
# ...

# %%
result = df[df["age"] > 50]

print(result)
# Out:
#       pclass                                           name     sex   age  \
# 6          1              Andrews, Miss. Kornelia Theodosia  female  63.0
# 8          1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 9          1                        Artagaveytia, Mr. Ramon    male  71.0
# 14         1           Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 33         1                       Bonnell, Miss. Elizabeth  female  58.0
# ...      ...                                            ...     ...   ...
# 1068       3                      Nysveen, Mr. Johan Hansen    male  61.0
# 1225       3                             Storey, Mr. Thomas    male  60.5
# 1235       3                            Svensson, Mr. Johan    male  74.0
# 1261       3                         Turkula, Mrs. (Hedwig)  female  63.0
# 1287       3               Widegren, Mr. Carl/Charles Peter    male  51.0
#
#       sibsp  parch    ticket     fare cabin embarked  survived
# ...

# %%
#fetch male passenger data who survived
df[(df["sex"] == "male") & (df["survived"] == 1)]
# Out:
#       pclass                                  name   sex      age  sibsp  \
# 1          1        Allison, Master. Hudson Trevor  male   0.9167      1
# 5          1                   Anderson, Mr. Harry  male  48.0000      0
# 14         1  Barkworth, Mr. Algernon Henry Wilson  male  80.0000      0
# 20         1         Beckwith, Mr. Richard Leonard  male  37.0000      1
# 22         1                 Behr, Mr. Karl Howell  male  26.0000      0
# ...      ...                                   ...   ...      ...    ...
# 1238       3            Tenglin, Mr. Gunnar Isidor  male  25.0000      0
# 1240       3       Thomas, Master. Assad Alexander  male   0.4167      0
# 1254       3          Tornquist, Mr. William Henry  male  25.0000      0
# 1256       3        Touma, Master. Georges Youssef  male   7.0000      1
# 1277       3                  Vartanian, Mr. David  male  22.0000      0
#
#       parch  ticket      fare    cabin embarked  survived
# ...

# %%
# fetch the data  from  pclass 2 and 3
df[df["pclass"].isin([2, 3])]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df[(df["pclass"]==1) | (df["pclass"]==3)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.describe(include=object)
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...
