# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Data-Analysis-Datasets/Datasets-Practice/hr_data.csv")
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
"""It will return the all the column names."""
df.columns
# Out:
# Index(['employee_id', 'number_project', 'average_montly_hours',
#        'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years',
#        'department', 'salary'],
#       dtype='object')

# %%
"""It will return different row"""
df.sample()
# Out:
#       employee_id  number_project  average_montly_hours  time_spend_company  \
# 9061        53526               5                   191                   3
#
#       Work_accident  left  promotion_last_5years department salary
# 9061              0     0                      0    support    low

# %%
df.sample(5)
# Out:
#       employee_id  number_project  average_montly_hours  time_spend_company  \
# 3190        19098               4                   218                   2
# 3188        86292               5                   143                   3
# 2290        13880               4                   167                   2
# 9256        54660               2                   149                   3
# 1893        11628               7                   302                   5
#
#       Work_accident  left  promotion_last_5years  department  salary
# 3190              0     0                      0  management  medium
# 3188              0     0                      0   technical  medium
# 2290              0     0                      0  accounting  medium
# 9256              0     0                      0       sales     low
# 1893              0     1                      0          IT  medium

# %%
df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
#it will return all the data of column for particular index
df.loc[22]
# Out:
# employee_id               1158
# number_project               6
# average_montly_hours       304
# time_spend_company           4
# Work_accident                0
# left                         1
# promotion_last_5years        0
# department               sales
# salary                     low
# Name: 22, dtype: object

# %%
#it will slice the  dataframe based on  slicing.  var.loc[st:en:step]
df.loc[22:100]
# Out:
#      employee_id  number_project  average_montly_hours  time_spend_company  \
# 22          1158               6                   304                   4
# 23          1166               2                   139                   3
# 24          1175               2                   158                   3
# 25          1184               5                   242                   5
# 26          1186               4                   239                   5
# ..           ...             ...                   ...                 ...
# 96          1610               6                   265                   4
# 97          1622               6                   279                   4
# 98          1639               6                   284                   4
# 99          1641               5                   221                   6
# 100         1642               2                   154                   3
#
#      Work_accident  left  promotion_last_5years department  salary
# ...

# %%
df.loc[[2,5,7],["department","salary"]]
# Out:
#   department  salary
# 2      sales  medium
# 5      sales     low
# 7      sales     low

# %%
df.loc[1:4, ["department","salary"]]  # range rows with specific columns
# Out:
#   department  salary
# 1      sales  medium
# 2      sales  medium
# 3      sales     low
# 4      sales     low

# %%
df.iloc[0]              # first row
# Out:
# employee_id               1003
# number_project               2
# average_montly_hours       157
# time_spend_company           3
# Work_accident                0
# left                         1
# promotion_last_5years        0
# department               sales
# salary                     low
# Name: 0, dtype: object

# %%
df.iloc[0:5]            # rows 0 to 4
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
df.iloc[:, 2]           # all rows, column index 2
# Out:
# 0        157
# 1        262
# 2        272
# 3        223
# 4        159
#         ...
# 14994    151
# 14995    160
# 14996    143
# 14997    280
# 14998    158
# Name: average_montly_hours, Length: 14999, dtype: int64

# %%
df.iloc[0:4, 1:3]       # row 0-3 & column 1-2
# Out:
#    number_project  average_montly_hours
# 0               2                   157
# 1               5                   262
# 2               7                   272
# 3               5                   223
