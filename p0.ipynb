# %% [markdown]
# # 🛠 Step-1: Create Virtual Environment
#
# - Run this command in your project folder:
#     python -m venv .venv
#
# # 🟢 Step-2: Activate Virtual Environment
# - On Windows
# - Command Prompt (cmd)
#     .venv\Scripts\activate
#
# # 🔴 Deactivate Virtual Environment
#     deactivate

# %% [markdown]
# # Data Science 💯
#
# - It is a process of extracting past data to train a model, so that model can predict Future.
